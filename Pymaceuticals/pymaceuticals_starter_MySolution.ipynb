# %% [markdown]
# ## Pymaceuticals Inc Data Analysis
# - Only 2 of the 10 drugs reduced tumor growth over 45 days (Capomulin and Ramicane)
# - Capomulin and Ramicane boasted the best survival rates (~84% and 80%, respectively)

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
drug_df = pd.read_csv(mouse_drug_data_to_load)
trial_df = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset
drug_trial_df = drug_df.merge(trial_df, how='outer', on='Mouse ID')

# Display the data table for preview
drug_trial_df.head(10)
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2
# 5     f234  Stelasyn         25           52.178602                 2
# 6     f234  Stelasyn         30           56.873817                 2
# 7     f234  Stelasyn         35           57.748758                 2
# 8     x402  Stelasyn          0           45.000000                 0
# 9     x402  Stelasyn          5           46.327570                 1

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
dt_group = drug_trial_df.groupby(['Drug', 'Timepoint'])

# Convert to DataFrame
tumor_mean = pd.DataFrame(dt_group['Tumor Volume (mm3)'].mean())
# Preview DataFrame
tumor_mean.head(15)
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
#           25                  39.939528
#           30                  38.769339
#           35                  37.816839
#           40                  36.958001
#           45                  36.236114
# Ceftamin  0                   45.000000
#           5                   46.503051
#           10                  48.285125
#           15                  50.094055
#           20                  52.157049

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
dt_group['Tumor Volume (mm3)'].sem()

# Convert to DataFrame
dt_sem_group = pd.DataFrame(dt_group['Tumor Volume (mm3)'].sem())

# Preview DataFrame
#dt_sem_group.head(15)

tv_sem_reformat = dt_sem_group.reset_index().pivot('Timepoint', 'Drug', 'Tumor Volume (mm3)')
tv_sem_reformat
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames
tumor_mean_reformat = tumor_mean.reset_index().pivot('Timepoint', 'Drug', 'Tumor Volume (mm3)')
# Preview that Reformatting worked
tumor_mean_reformat
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
tumor_mean_reformat.index
# Out:
# Int64Index([0, 5, 10, 15, 20, 25, 30, 35, 40, 45], dtype='int64', name='Timepoint')

# %%
tumor_mean_reformat.columns
# Out:
# Index(['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo',
#        'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol'],
#       dtype='object', name='Drug')

# %%
# Generate the Plot (with Error Bars)

#markers = ['.', ',', 'o', 'v', 's', '<', '>', '*', '+', 'x', '']

for x in range(len(tumor_mean_reformat.index)):
    plt.errorbar(tumor_mean_reformat.index, tumor_mean_reformat.iloc[:,x], tv_sem_reformat.iloc[:,x], marker='o')

#plt.plot(x=tumor_mean_reformat.index, y=[tumor_mean_reformat['Capomulin'], tumor_mean_reformat['Ceftamin']])
plt.xlabel("Time (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Tumor Response to Treatment")
plt.legend(loc="best")
plt.grid()
#plt.errorbar(dt_sem_group)

# Save the Figure
plt.savefig('Tumor Response.png')

# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 

# Convert to DataFrame
meta_mean = pd.DataFrame(dt_group['Metastatic Sites'].mean())
# Preview DataFrame
meta_mean.head(15)
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174
#           25                 0.818182
#           30                 1.090909
#           35                 1.181818
#           40                 1.380952
#           45                 1.476190
# Ceftamin  0                  0.000000
#           5                  0.380952
#           10                 0.600000
#           15                 0.789474
#           20                 1.111111

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
dt_group['Metastatic Sites'].sem()
# Convert to DataFrame
dt_meta_sem_group = pd.DataFrame(dt_group['Metastatic Sites'].sem())
# Preview DataFrame
#dt_meta_sem_group.head(15)

meta_sem_reformat = dt_meta_sem_group.reset_index().pivot('Timepoint', 'Drug', 'Metastatic Sites')
# Preview that Reformatting worked
meta_sem_reformat
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames
meta_mean_reformat = meta_mean.reset_index().pivot('Timepoint', 'Drug', 'Metastatic Sites')
# Preview that Reformatting worked
meta_mean_reformat
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)

markers = ['.', ',', 'o', 'v', 's', '<', '>', '*', '+', 'x', '']

#fig, ax = plt.subplots()

for x in range(len(meta_mean_reformat.index)):
    plt.errorbar(meta_mean_reformat.index, meta_mean_reformat.iloc[:,x], meta_sem_reformat.iloc[:,x], marker='o')

#plt.errorbar(meta_mean_reformat.index, meta_mean_reformat.iloc[:,x], xerr=0.5, fmt='o')

plt.xlabel("Treatment Duration (Days)")
plt.ylabel("Met. Sites")
plt.title("Metastatic Spread During Treatment")
plt.legend(loc="best")
plt.grid()

# Save the Figure
plt.savefig('Metastatic Spread.png')

# Show the Figure
plt.show()

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)


# Convert to DataFrame
survival_df = pd.DataFrame(dt_group['Tumor Volume (mm3)'].count())
survival_df.rename(columns={'Tumor Volume (mm3)': 'Mouse Count'}, inplace=True)
# Preview DataFrame
survival_df.head(15)
# Out:
#                      Mouse Count
# Drug      Timepoint
# Capomulin 0                   25
#           5                   25
#           10                  25
#           15                  24
#           20                  23
#           25                  22
#           30                  22
#           35                  22
#           40                  21
#           45                  21
# Ceftamin  0                   25
#           5                   21
#           10                  20
#           15                  19
#           20                  18

# %%
# Minor Data Munging to Re-Format the Data Frames
survival_df_reformat = survival_df.reset_index().pivot('Timepoint', 'Drug', 'Mouse Count')
# Preview the Data Frame
survival_df_reformat
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %%
# Generate the Plot (Accounting for percentages)
markers = ['.', ',', 'o', 'v', 's', '<', '>', '*', '+', 'x', '']

for x in range(len(survival_df_reformat.index)):
    plt.errorbar(survival_df_reformat.index, (survival_df_reformat.iloc[:,x]/survival_df_reformat.iloc[0,x]) * 100, marker=markers[x])

plt.xlabel("Time (Days)")
plt.ylabel("Survival Rate (%)")
plt.title("Survival During Treatment")
plt.legend(loc="best")
plt.grid()

# Save the Figure
plt.savefig('Survival.png')

# Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
tumor_mean_reformat
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
last_row = 9
first_row = 0

# Calculate the percent changes for each drug
percent_change = ((tumor_mean_reformat.iloc[last_row,:] - tumor_mean_reformat.iloc[first_row, :])/tumor_mean_reformat.iloc[first_row, :]) * 100

# Display the data to confirm
percent_change

percent_change_df = pd.DataFrame(percent_change, columns=['Percent Tumor Change'])
percent_change_df
# Out:
#            Percent Tumor Change
# Drug
# Capomulin            -19.475303
# Ceftamin              42.516492
# Infubinol             46.123472
# Ketapril              57.028795
# Naftisol              53.923347
# Placebo               51.297960
# Propriva              47.241175
# Ramicane             -22.320900
# Stelasyn              52.085134
# Zoniferol             46.579751

# %%
# Create a new column that displays True if the tumor decreased or False if the tumor increased
percent_change_df['Tumor Reduction?'] = percent_change_df['Percent Tumor Change'] < 0

# Display the updated df
percent_change_df
# Out:
#            Percent Tumor Change  Tumor Reduction?
# Drug
# Capomulin            -19.475303              True
# Ceftamin              42.516492             False
# Infubinol             46.123472             False
# Ketapril              57.028795             False
# Naftisol              53.923347             False
# Placebo               51.297960             False
# Propriva              47.241175             False
# Ramicane             -22.320900              True
# Stelasyn              52.085134             False
# Zoniferol             46.579751             False

# %%
# Create a list of colors based on the values in 'Tumor Reduction?' col
# If the value in the col is True, the tumor decreased, therefore the associated color is green
# If the value in the col is False, the tumor increased, therefore the associated color is red
colors = []
for x in range(len(percent_change_df['Tumor Reduction?'])):
    if percent_change_df['Tumor Reduction?'][x] == True:
        colors.append('green')
    else:
        colors.append('red')
print(colors)
# Out:
# ['green', 'red', 'red', 'red', 'red', 'red', 'red', 'green', 'red', 'red']

# %%
# Orient widths. Add labels, tick marks, etc. 
fig, ax = plt.subplots()
rects1 = ax.bar(percent_change_df.index, percent_change_df['Percent Tumor Change'], align='edge', width=1, color=colors)
plt.xlabel("Drug")
plt.ylabel("% Tumor Volume Change")
plt.title("Tumor Change Over 45 Days Treatment")
plt.grid()
plt.xticks(rotation='vertical')
plt.ylim(-30,70)

# Use functions to label the percentages of changes
def autolabel(rects, ax):
    # Get y-axis height to calculate label position from.
    (y_bottom, y_top) = ax.get_ylim()
    y_height = y_top - y_bottom

    for rect in rects:
        height = rect.get_height()

        # Fraction of axis height taken up by this rectangle
        p_height = (height / y_height)

        # If we can fit the label above the column, do that;
        # otherwise, put it inside the column.
        if p_height > 0.95: # arbitrary; 95% looked good to me.
            label_position = height - (y_height * 0.05)
        else:
            label_position = height + (y_height * 0.01)

        ax.text(rect.get_x() + rect.get_width()/2., label_position, f'{int(height)}%', ha='center', va='bottom')

# Call functions to implement the function calls
autolabel(rects1, ax)

# Save the Figure
plt.savefig('Tumor Change.png')

# Show the Figure
plt.show()
